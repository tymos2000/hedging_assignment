# %%
import importlib.util
import subprocess
import sys

def install_package(package_name):
    subprocess.check_call([sys.executable, "-m", "pip", "install", package_name])

def check_package(package_name):
    spec = importlib.util.find_spec(package_name)
    if spec is None:
        print(f"{package_name} is not installed. Installing...")
        install_package(package_name)
        print(f"...ready.")
    else:
        print(f"{package_name} is already installed.")

check_package("pyfinance")
# Out:
# pyfinance is not installed. Installing...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 11.3 MB/s eta 0:00:00
# ...
# ...ready.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
from pyfinance.options import BSM

import numpy as np

def pricediff(sigma):
    d1 = (np.log(S/E) + (r + sigma ** 2 / 2) * (T - t)) / (sigma * np.sqrt(T - t))
    d2 = (np.log(S/E) + (r - sigma ** 2 / 2) * (T - t)) / (sigma * np.sqrt(T - t))
    Nd_plus= norm.cdf(d1)
    Nd_minus = norm.cdf(d2)
    C = S*Nd_plus - E * np.exp(-r*(T-t))*Nd_minus
    a = Ubs - C
    return a
        
S = 141.86  #underlying first day
E = 135
r = 0.04
a =0.00000001
b = 1
T = 63/365
t = 0
Ubs = 10.79 #option market price



for i in range (30):
    m1 = 0.5*(a + b)
    f = pricediff(a)
    g = pricediff(b)
    h = pricediff(m1)
    if(h<0):
        b = m1
    else:
        a = m1
    i = i+1


print(m1) 
print(pricediff(m1))
# Out:
# 0.26800929276243834
# -1.3163905521196284e-08

# %%
d1 = (np.log(S/E) + (r + m1 ** 2 / 2) * (T - t)) / (m1 * np.sqrt(T - t)) #from bse
delta = norm.cdf(d1)
print(delta)

pi_2 = delta * S #second portfolio

S2 = 141.49
u2 = 10.8

pi2_n = delta * S2 #second portfolio second day
diffRE = pi2_n - pi_2
diffOG = u2 - Ubs #market price second - first day
print(diffRE)
print(diffOG)

rel_diff = (diffRE - diffOG)/diffOG
print(rel_diff)
# Out:
# 0.7132252580924635
# -0.24050000000001148
# 0.010000000000001563
# -25.04999999999739

# %%
def portfoliodiff()
