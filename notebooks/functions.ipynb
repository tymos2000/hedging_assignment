# %%
def norehedge(S1, S2, delta):
    diffRE = delta * (S2 - S1)
    diffOG = pi1_n - pi1
    A0 = diffOG - diffRE
    return A0

def rehedge(t):
    diffRE = delta * (S2 - S1)
    diffOG = pi1_n - pi1
    A0 = diffOG - diffRE
    #computing new volatility
    for i in range (30):
        m1 = 0.5*(a + b)
        f = pricediff(a)
        g = pricediff(b)
        h = pricediff(m1)
        if(h<0):
            b = m1
        else:
            a = m1
        i = i+1
        delta = norm.cdf(d1)
    return A0

A = []

#t is the second day
for t in days:
    if t%2 != 0: #if odd day dont rehedge
        A[t] = norehedge(S[t-1], S[t], delta)
    else: 
        delta, A[t] = rehedge(S[t-1], S[t], delta)
